# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# My name is **Ashish Kumar Sahoo**
# I want to be a data scientist.

# %% [markdown]
# _I am interested in data science because of my core interest in neuroscience, especially neuroscience.
# Computational neuroscience deals with large amounts of data generated using various instruments such as fMRI, and analysis of such data is what I would like to do as a data scientist._

# %% [markdown]
# ### The code is Cell 5 is supposed to print "Hello World".

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# ###### Horizontal rule
# ___
#
# ###### Lists
#   * Bulleted list
#
#
# 1. Numbered list
#
#
# ###### Hyperlink
# [Youtube](https://youtube.com)
#
# ###### Images
# Markdown logo (hover to see the title text):
#
# Inline-style:
# ![alt text](https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png "Inline style")
#
# Reference-style:
# ![alt text][logo]
#
# [logo]: https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png "Reference style"
#
# ###### Code/Syntax highlighting
# `Back-ticks needed for code highlighting`
#
# ###### Blockquotes
# > This is how blockquotes is done
#
# ###### Strikethrough
# ~~This is how you strikethrough~~
